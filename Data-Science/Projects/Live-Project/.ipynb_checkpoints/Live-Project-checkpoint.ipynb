# %% [markdown]
# # Live Project:
#
#
# ### Eyeballing information:
#
# ###### 1.) File format is excel
# ###### 2.) There are 5 sheets: Analysis Summary, Expenses details, Inward Cash Flow. Bank Account Reconsilition, Details
# ###### 3.) Details tells the categorisation of Expence type and Exp Source
# ###### 4.) There are multiple unnecessary blank spaces
# ###### 5.) Expence Detials is based on only counter book (ONLY)
# ###### 6.) The range of Expence data is from 1st Jan 2023 to 21st July 2023
# ###### 7.) Difference in Total Expence(24,20,492) and  Cash Inflow(64,79,004) is 40,58,512
#
#
# ### What to do:
#
# ###### 1.)Using pandas is recommended for data cleaning
# ###### 2.)Check for missing values or missing data
# ###### 3.)Removal of unncessary column is advised
# ###### 4.)Removal of seperation rows in advised
#
# ### Observation:
#
# ###### 1.) No Beverage sold in the given time,
# ###### 2.) Salary and Petrol are the most repeated tasks(Automation of salary calculation should be done on basis of attendance)
# ###### 3.) For Feb. and Mar. their was no payment of Chicken
# ###### 4.) Payment for Mutton and Fish was done only once in the complete 7 month time span

# %%
import pandas as pd #imported pandas
import numpy as np #imported numpy
np.set_printoptions(suppress = True,
                   linewidth = 100,
                   precision = 2)

# %%
expense_details = pd.read_excel("Sales Summary.xlsx", sheet_name="Expenses details")

# %%
expense_details
# Out:
#            Date Month         Expense Details  Amount   Catagory    Exp Source
# 0    2023-01-01   Jan             HPGas big 1  1950.0     02_Gas  Counter Book
# 1    2023-01-01   Jan            Live singing  5000.0    03_Misc  Counter Book
# 2    2023-01-01   Jan  Suraj waiter (Adv Dec)  2000.0  04_Salary  Counter Book
# 3    2023-01-01   Jan  Ganesh Kumre (Adv Dec)   500.0  04_Salary  Counter Book
# 4    2023-01-01   Jan        Yogesh (Adv Dec)  1000.0  04_Salary  Counter Book
# ...         ...   ...                     ...     ...        ...           ...
# 1122 2023-07-20  July    Yuvraj full sal June  6500.0  04_Salary  Counter Book
# 1123        NaT   NaN                     NaN     NaN        NaN           NaN
# 1124 2023-07-21  July            French fries   380.0   01_Dairy  Counter Book
# 1125 2023-07-21  July                  Corn 2   240.0   01_Dairy  Counter Book
# 1126 2023-07-21  July    Pankaj full sal June  7800.0  04_Salary  Counter Book
#
# [1127 rows x 6 columns]

# %%
expense_details = expense_details.dropna(how='all')
#removed unnecessary blank rows

# %%
expense_details
# Out:
#            Date Month         Expense Details  Amount   Catagory    Exp Source
# 0    2023-01-01   Jan             HPGas big 1  1950.0     02_Gas  Counter Book
# 1    2023-01-01   Jan            Live singing  5000.0    03_Misc  Counter Book
# 2    2023-01-01   Jan  Suraj waiter (Adv Dec)  2000.0  04_Salary  Counter Book
# 3    2023-01-01   Jan  Ganesh Kumre (Adv Dec)   500.0  04_Salary  Counter Book
# 4    2023-01-01   Jan        Yogesh (Adv Dec)  1000.0  04_Salary  Counter Book
# ...         ...   ...                     ...     ...        ...           ...
# 1121 2023-07-20  July          Ankit July adv  1000.0  04_Salary  Counter Book
# 1122 2023-07-20  July    Yuvraj full sal June  6500.0  04_Salary  Counter Book
# 1124 2023-07-21  July            French fries   380.0   01_Dairy  Counter Book
# 1125 2023-07-21  July                  Corn 2   240.0   01_Dairy  Counter Book
# 1126 2023-07-21  July    Pankaj full sal June  7800.0  04_Salary  Counter Book
#
# [946 rows x 6 columns]

# %%
expense_details.to_excel("Expense-Details.xlsx", index = False)
#created a back-up

# %%
expense_details.drop("Month",axis=1,inplace=True)
#No need of months column the dates show the month
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13216\1269580459.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expense_details.drop("Month",axis=1,inplace=True)

# %%
expense_details
# Out:
#            Date         Expense Details  Amount   Catagory    Exp Source
# 0    2023-01-01             HPGas big 1  1950.0     02_Gas  Counter Book
# 1    2023-01-01            Live singing  5000.0    03_Misc  Counter Book
# 2    2023-01-01  Suraj waiter (Adv Dec)  2000.0  04_Salary  Counter Book
# 3    2023-01-01  Ganesh Kumre (Adv Dec)   500.0  04_Salary  Counter Book
# 4    2023-01-01        Yogesh (Adv Dec)  1000.0  04_Salary  Counter Book
# ...         ...                     ...     ...        ...           ...
# 1121 2023-07-20          Ankit July adv  1000.0  04_Salary  Counter Book
# 1122 2023-07-20    Yuvraj full sal June  6500.0  04_Salary  Counter Book
# 1124 2023-07-21            French fries   380.0   01_Dairy  Counter Book
# 1125 2023-07-21                  Corn 2   240.0   01_Dairy  Counter Book
# 1126 2023-07-21    Pankaj full sal June  7800.0  04_Salary  Counter Book
#
# [946 rows x 5 columns]

# %%
expense_details["Exp Source"].unique()
#checking if there is any other source of expences
# Out:
# array(['Counter Book'], dtype=object)

# %%
expense_details.drop("Exp Source", axis=1, inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13216\2498295097.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expense_details.drop("Exp Source", axis=1, inplace=True)

# %%
expense_details
# Out:
#            Date         Expense Details  Amount   Catagory
# 0    2023-01-01             HPGas big 1  1950.0     02_Gas
# 1    2023-01-01            Live singing  5000.0    03_Misc
# 2    2023-01-01  Suraj waiter (Adv Dec)  2000.0  04_Salary
# 3    2023-01-01  Ganesh Kumre (Adv Dec)   500.0  04_Salary
# 4    2023-01-01        Yogesh (Adv Dec)  1000.0  04_Salary
# ...         ...                     ...     ...        ...
# 1121 2023-07-20          Ankit July adv  1000.0  04_Salary
# 1122 2023-07-20    Yuvraj full sal June  6500.0  04_Salary
# 1124 2023-07-21            French fries   380.0   01_Dairy
# 1125 2023-07-21                  Corn 2   240.0   01_Dairy
# 1126 2023-07-21    Pankaj full sal June  7800.0  04_Salary
#
# [946 rows x 4 columns]

# %%
expense_details["Catagory"].unique()
# Out:
# array(['02_Gas', '03_Misc', '04_Salary', '04_Samaj seva', '03_Petrol', '01_Kirana',
#        '02_Electric bill', '04_ODC', '03_Cash Return', '01_Dairy', '03_Room Rent', '01_Vegetables',
#        '01_Non Veg', '04_Salary OT', '03_Maintainance', '01_Egg', '02_Coal', '01_Mutton',
#        '01_Chicken', '01_Fish'], dtype=object)

# %%
len(expense_details["Catagory"].unique())
#So there are in total 20 unique places where the money has been used
# Out:
# 20

# %%
expense_details["Catagory"].value_counts()
# Out:
# Catagory
# 04_Salary           417
# 03_Petrol           118
# 02_Gas               92
# 03_Misc              84
# 03_Maintainance      35
# 01_Kirana            32
# 04_Samaj seva        29
# 03_Cash Return       28
# 04_ODC               24
# 01_Dairy             18
# 01_Vegetables        17
# 04_Salary OT         15
# 03_Room Rent         11
# 02_Electric bill      9
# 02_Coal               6
# 01_Non Veg            3
# 01_Egg                3
# 01_Chicken            3
# 01_Mutton             1
# 01_Fish               1
# Name: count, dtype: int64

# %%
expense_details["Expense Details"].unique()
#this given the various unique values or in simple words where the money was spent
# Out:
# array(['HPGas big 1', 'Live singing', 'Suraj waiter (Adv Dec)', 'Ganesh Kumre (Adv Dec)',
#        'Yogesh (Adv Dec)', 'Ankit chef (Adv Dec)', 'Rakesh waiter (Full salary Nov)',
#        'Rakesh waiter (Adv Dec)', 'Ashok vat electricity balance', 'Samaj seva ', 'Omni Petrol',
#        'Hp Gas small2', 'Tea', 'Tija bai (Adv Dec)', 'Vinod chef (Adv Dec)',
#        'Kapil Chef (Adv Dec)', 'Dilip kaka (Adv Dec)', 'Omni petrol', 'Aniket Chef (Adv Dec)',
#        'Wheel powder', 'Samaj seva', 'HP Gas small 2', 'Ajay (Adv Dec)',
#        'Boys room electricity bill', 'Girls room rent (November month)',
#        'Sunita bai divakar (Adv Dec)', 'HP Gas small 1', 'Bonfire Lakdi', 'Ajay sir (Adv Dec)',
#        'HP Gas big 1', 'Golu ODC', 'Corn flour', 'Dhiraj verma (Adv Dec)',
#        'Pooja waiter (Adv Dec)', 'Mona waiter (Adv Dec)', 'Party decoration', 'Cash return',
#        'Bike petrol', 'Kapil chef (Adv Dec)', 'Ankit (Adv Dec)', 'Bonfire lakdi',
# ...

# %%
len(expense_details["Expense Details"].unique())
#the exact number of unique values or unique reason why money was spent
# Out:
# 637

# %%
expense_details["Expense Details"].value_counts()
#how many time the given action was repeated
# Out:
# Expense Details
# Bike petrol               45
# Omni petrol               41
# HP Gas small 1            24
# HP gas small 1            19
# Samaj seva                19
#                           ..
# Sarswati bai (Feb adv)     1
# Omlal (Feb adv)            1
# Cash return (M4)           1
# Sumitra Bai (Feb adv)      1
# Pankaj full sal June       1
# Name: count, Length: 636, dtype: int64

# %%
expense_details["Expense Details"].value_counts().to_excel("Unique-Expense-Details.xlsx")
#the unique places where the money was spent was saved for further understanding

# %%
expense_details.set_index("Date",inplace=True)

# %%
expense_details
# Out:
#                    Expense Details  Amount   Catagory
# Date
# 2023-01-01             HPGas big 1  1950.0     02_Gas
# 2023-01-01            Live singing  5000.0    03_Misc
# 2023-01-01  Suraj waiter (Adv Dec)  2000.0  04_Salary
# 2023-01-01  Ganesh Kumre (Adv Dec)   500.0  04_Salary
# 2023-01-01        Yogesh (Adv Dec)  1000.0  04_Salary
# ...                            ...     ...        ...
# 2023-07-20          Ankit July adv  1000.0  04_Salary
# 2023-07-20    Yuvraj full sal June  6500.0  04_Salary
# 2023-07-21            French fries   380.0   01_Dairy
# 2023-07-21                  Corn 2   240.0   01_Dairy
# 2023-07-21    Pankaj full sal June  7800.0  04_Salary
#
# [946 rows x 3 columns]

# %%
#As from further analysis it is Observed that the non-veg was nothing but Chicken so we are replacing the same
replace_nonVeg = {"01_Non Veg":"01_Chicken"}
expense_details.replace({"Catagory":replace_nonVeg},inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13216\44519390.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expense_details.replace({"Catagory":replace_nonVeg},inplace=True)

# %%
expense_details
# Out:
#                    Expense Details  Amount   Catagory
# Date
# 2023-01-01             HPGas big 1  1950.0     02_Gas
# 2023-01-01            Live singing  5000.0    03_Misc
# 2023-01-01  Suraj waiter (Adv Dec)  2000.0  04_Salary
# 2023-01-01  Ganesh Kumre (Adv Dec)   500.0  04_Salary
# 2023-01-01        Yogesh (Adv Dec)  1000.0  04_Salary
# ...                            ...     ...        ...
# 2023-07-20          Ankit July adv  1000.0  04_Salary
# 2023-07-20    Yuvraj full sal June  6500.0  04_Salary
# 2023-07-21            French fries   380.0   01_Dairy
# 2023-07-21                  Corn 2   240.0   01_Dairy
# 2023-07-21    Pankaj full sal June  7800.0  04_Salary
#
# [946 rows x 3 columns]

# %%
expense_details["Catagory"].value_counts()
#segregation by established category
# Out:
# Catagory
# 04_Salary           417
# 03_Petrol           118
# 02_Gas               92
# 03_Misc              84
# 03_Maintainance      35
# 01_Kirana            32
# 04_Samaj seva        29
# 03_Cash Return       28
# 04_ODC               24
# 01_Dairy             18
# 01_Vegetables        17
# 04_Salary OT         15
# 03_Room Rent         11
# 02_Electric bill      9
# 01_Chicken            6
# 02_Coal               6
# 01_Egg                3
# 01_Mutton             1
# 01_Fish               1
# Name: count, dtype: int64

# %%
np.where(expense_details["Expense Details"].isnull())
#found null value
# Out:
# (array([353], dtype=int64),)

# %%
expense_details["Expense Details"].isnull().index[353]
#null value index
# Out:
# Timestamp('2023-03-10 00:00:00')

# %% [markdown]
# ###### This index has the amount 30 and Category 03_Misc, it can be neglected but until further instruction noting will be done
# But for now I will drop it to continue analysis

# %%
# Modify the original DataFrame 'df' by dropping rows containing null values
expense_details.dropna(inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13216\1676923849.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expense_details.dropna(inplace=True)

# %%
expense_details
# Out:
#                    Expense Details  Amount   Catagory
# Date
# 2023-01-01             HPGas big 1  1950.0     02_Gas
# 2023-01-01            Live singing  5000.0    03_Misc
# 2023-01-01  Suraj waiter (Adv Dec)  2000.0  04_Salary
# 2023-01-01  Ganesh Kumre (Adv Dec)   500.0  04_Salary
# 2023-01-01        Yogesh (Adv Dec)  1000.0  04_Salary
# ...                            ...     ...        ...
# 2023-07-20          Ankit July adv  1000.0  04_Salary
# 2023-07-20    Yuvraj full sal June  6500.0  04_Salary
# 2023-07-21            French fries   380.0   01_Dairy
# 2023-07-21                  Corn 2   240.0   01_Dairy
# 2023-07-21    Pankaj full sal June  7800.0  04_Salary
#
# [945 rows x 3 columns]

# %%
expense_details.to_excel("New-Expense-Details.xlsx")
#Created a seperate file for the updated expenses and removing index

# %%
update_expense_details = pd.read_excel("New-Expense-Details.xlsx", index_col="Date")
#Reassigning value

# %%
update_expense_details.isnull().sum()
#So there are no missing values
# Out:
# Expense Details    0
# Amount             0
# Catagory           0
# dtype: int64

# %% [markdown]
# <hr style="border: 2px solid black;">

# %% [markdown]
# # The Sub Categorisation Begins here...

# %% [markdown]
# <hr style="border: 2px solid black;">

# %%
loop_output_subcat ={}
for i in expense_details["Expense Details"].unique():
    key = f'{i}'
    details=expense_details[expense_details["Expense Details"].str.startswith(i)]["Amount"].array.sum()
    loop_output_subcat[key]=details

# %%
loop_output_subcat
# Out:
# {'HPGas big 1': 1950.0,
#  'Live singing': 8200.0,
#  'Suraj waiter (Adv Dec)': 2000.0,
#  'Ganesh Kumre (Adv Dec)': 600.0,
#  'Yogesh (Adv Dec)': 1300.0,
#  'Ankit chef (Adv Dec)': 2500.0,
#  'Rakesh waiter (Full salary Nov)': 5630.0,
#  'Rakesh waiter (Adv Dec)': 4370.0,
#  'Ashok vat electricity balance': 5000.0,
#  'Samaj seva ': 59850.0,
#  'Omni Petrol': 3000.0,
#  'Hp Gas small2': 2300.0,
#  'Tea': 100.0,
#  'Tija bai (Adv Dec)': 2000.0,
#  'Vinod chef (Adv Dec)': 4000.0,
#  'Kapil Chef (Adv Dec)': 2000.0,
#  'Dilip kaka (Adv Dec)': 1600.0,
#  'Omni petrol': 21500.0,
#  'Aniket Chef (Adv Dec)': 500.0,
#  'Wheel powder': 222.0,
#  'Samaj seva': 236540.0,
#  'HP Gas small 2': 6900.0,
#  'Ajay (Adv Dec)': 1000.0,
#  'Boys room electricity bill': 4050.0,
#  'Girls room rent (November month)': 2500.0,
#  'Sunita bai divakar (Adv Dec)': 2000.0,
#  'HP Gas small 1': 33360.0,
#  'Bonfire Lakdi': 1550.0,
#  'Ajay sir (Adv Dec)': 3000.0,
#  'HP Gas big 1': 12050.0,
# ...

# %%
sub_cat = pd.DataFrame(loop_output_subcat, index=range(1))

# %%
sub_cat
# Out:
#    HPGas big 1  Live singing  Suraj waiter (Adv Dec)  Ganesh Kumre (Adv Dec)  \
# 0       1950.0        8200.0                  2000.0                   600.0
#
#    Yogesh (Adv Dec)  Ankit chef (Adv Dec)  Rakesh waiter (Full salary Nov)  \
# 0            1300.0                2500.0                           5630.0
#
#    Rakesh waiter (Adv Dec)  Ashok vat electricity balance  Samaj seva   ...  \
# 0                   4370.0                         5000.0      59850.0  ...
#
#       Coal  Dhiraj July adv  Ankit Full sal  Shubham full sal June  \
# 0  32400.0            603.0          8500.0                 5200.0
#
#    Sunny July adv  Ankit July adv  Yuvraj full sal June  French fries  Corn 2  \
# 0          2000.0          1000.0                6500.0         380.0   240.0
#
#    Pankaj full sal June
# 0                7800.0
#
# [1 rows x 636 columns]

# %%
sub_cat=sub_cat.T

# %%
sub_cat.to_excel("Sub-Cateogrised=Expenses-ALL.xlsx")

# %%
loop_output_subcat = {}
seen_keys = {}

for i in expense_details["Expense Details"]:
    key = f'{i}'
    
    # Check if the key already exists
    if key in seen_keys:
        # If it does, append a numeric suffix to make it unique
        seen_keys[key] += 1
        key = f'{i} ({seen_keys[key]})'
    else:
        # If it doesn't exist, add it to the seen_keys dictionary
        seen_keys[key] = 0
    
    details = expense_details[expense_details["Expense Details"].str.startswith(i)]["Amount"].array.sum()
    loop_output_subcat[key] = details

# %%
pankaj_salary = update_expense_details[update_expense_details["Expense Details"].str.startswith('Pankaj')]

# %%
len(pankaj_salary)
# Out:
# 9

# %%
pankaj_salary
# Out:
#                             Expense Details  Amount   Catagory
# Date
# 2023-03-26          Pankaj chef (March adv)    1000  04_Salary
# 2023-04-03          Pankaj chef (March adv)    1000  04_Salary
# 2023-04-16  Pankaj chef (March full salary)    2000  04_Salary
# 2023-05-13    Pankaj chef April full salary    5000  04_Salary
# 2023-05-24             Pankaj chef May adv.     500  04_Salary
# 2023-05-28              Pankaj chef May adv    3500  04_Salary
# 2023-06-17    Pankaj chef (May full salary)    7000  04_Salary
# 2023-06-26                      Pankaj chef     500  04_Salary
# 2023-07-21             Pankaj full sal June    7800  04_Salary

# %%
pankaj_salary["Amount"].array
# Out:
# <PandasArray>
# [1000, 1000, 2000, 5000, 500, 3500, 7000, 500, 7800]
# Length: 9, dtype: int64

# %%
pankaj_salary["Amount"].array.sum()
# Out:
# 28300

# %% [markdown]
# <hr style="border: 2px solid black;">

# %%
HP_gas = update_expense_details[update_expense_details["Expense Details"].str.startswith('HP')]

# %%
HP_gas
# Out:
#            Expense Details  Amount Catagory
# Date
# 2023-01-01     HPGas big 1    1950   02_Gas
# 2023-01-05  HP Gas small 2    2300   02_Gas
# 2023-01-07  HP Gas small 1    1150   02_Gas
# 2023-01-08  HP Gas small 1    1150   02_Gas
# 2023-01-08    HP Gas big 1    1950   02_Gas
# ...                    ...     ...      ...
# 2023-05-22  HP Gas small 1    1200   02_Gas
# 2023-05-23  HP gas small 1    1200   02_Gas
# 2023-05-25  HP gas small 1    1200   02_Gas
# 2023-05-28    HP gas big 1    2060   02_Gas
# 2023-06-09  HP gas small 2    2400   02_Gas
#
# [81 rows x 3 columns]

# %%
HP_gas["Amount"].array
# Out:
# <PandasArray>
# [1950, 2300, 1150, 1150, 1950, 1150, 1150, 1150, 1150, 1950, 2300, 2300, 1160,
#  1950, 1150, 1150, 1150, 1150, 1150, 1150, 1950, 1150, 1150, 1150, 1150, 1950,
#  1150, 3100, 1150, 1950, 1150, 1150, 1150, 1150, 1950, 1200, 2300, 1200, 1200,
#  2300, 1200, 1200, 2400, 2300, 1200, 1700, 2300, 8500, 2230, 1200, 1200, 2230,
#  2400, 2230, 1200, 3430, 1200, 1200, 2230, 1200, 1200, 1200, 1200, 2230, 1200,
#  2400, 2170, 1200, 1200, 1200, 1200, 2160, 1200, 1200, 1200, 2060, 1200, 1200,
#  1200, 2060, 2400]
# Length: 81, dtype: int64

# %%
HP_gas["Amount"].array.sum()
# Out:
# 135290

# %%
len(HP_gas["Amount"].array)
# Out:
# 81

# %% [markdown]
# <hr style="border: 2px solid black;">

# %%
Kirana =  update_expense_details[update_expense_details["Catagory"].str.startswith("01_Kirana")]

# %%
Kirana
# Out:
#                               Expense Details  Amount   Catagory
# Date
# 2023-01-02                                Tea      50  01_Kirana
# 2023-01-04                       Wheel powder     150  01_Kirana
# 2023-01-08                         Corn flour     280  01_Kirana
# 2023-01-10                              Sugar      40  01_Kirana
# 2023-01-20                            Vinegar      30  01_Kirana
# 2023-01-21                        Gulab Jamun     200  01_Kirana
# 2023-01-26                 Chai patti (2 pkt)      50  01_Kirana
# 2023-01-28                   Agarbati (1 pkt)      50  01_Kirana
# 2023-02-08                            Noodles      50  01_Kirana
# 2023-02-17                         Sugar 1 kg      40  01_Kirana
# 2023-02-21                        Oil (3 pkt)     390  01_Kirana
# 2023-02-26                         Bush color     140  01_Kirana
# 2023-03-06                       Ajay kirana      400  01_Kirana
# ...

# %%
len(Kirana)
# Out:
# 32

# %%
Oil = update_expense_details[update_expense_details["Expense Details"].str.startswith("Oil")]

# %%
Oil
# Out:
#            Expense Details  Amount   Catagory
# Date
# 2023-02-21     Oil (3 pkt)     390  01_Kirana
# 2023-03-09       Oil 2 pkt     250  01_Kirana
# 2023-03-14             Oil     500  01_Kirana
# 2023-03-16        Oil 2pkt     270  01_Kirana
# 2023-04-02      Oil (5 kg)     700  01_Kirana
# 2023-04-04        Oil 5 kg     630  01_Kirana
# 2023-06-29       Oil 3 pkt     330  01_Kirana

# %%
Oil["Amount"].array.sum()
# Out:
# 3070

# %%
len(Oil)
# Out:
# 7

# %%
Wheelpowder = update_expense_details[update_expense_details["Expense Details"].str.startswith("Wheel")]

# %%
Wheelpowder
# Out:
#               Expense Details  Amount   Catagory
# Date
# 2023-01-04       Wheel powder     150  01_Kirana
# 2023-05-18  Wheel powder 1 kg      72  01_Kirana

# %%
Wheelpowder["Amount"].array
# Out:
# <PandasArray>
# [150, 72]
# Length: 2, dtype: int64

# %%
Wheelpowder["Amount"].array.sum()
# Out:
# 222

# %%
len(Wheelpowder)
# Out:
# 2

# %%
Cornflour = update_expense_details[update_expense_details["Expense Details"].str.startswith("Corn")]

# %%
Cornflour
# Out:
#            Expense Details  Amount   Catagory
# Date
# 2023-01-08      Corn flour     280  01_Kirana
# 2023-07-21          Corn 2     240   01_Dairy

# %%
Sugar = update_expense_details[update_expense_details["Expense Details"].str.startswith("Sugar")]

# %%
Sugar
# Out:
#            Expense Details  Amount   Catagory
# Date
# 2023-01-10           Sugar      40  01_Kirana
# 2023-02-17      Sugar 1 kg      40  01_Kirana
# 2023-03-23       Sugar 1kg      45  01_Kirana

# %%
Sugar["Amount"].array.sum()
# Out:
# 125

# %%
len(Sugar)
# Out:
# 3

# %%
Vinegar = update_expense_details[update_expense_details["Expense Details"].str.startswith("Vine")]

# %%
Vinegar
# Out:
#            Expense Details  Amount   Catagory
# Date
# 2023-01-20         Vinegar      30  01_Kirana

# %%
BushColour = update_expense_details[update_expense_details["Expense Details"].str.startswith("Bush")]

# %% [markdown]
# <hr style="border: 2px solid black;">
