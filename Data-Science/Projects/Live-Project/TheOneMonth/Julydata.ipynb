# %% [markdown]
# ### Following Data is restricted to July data of DND hotel
#
# #### Observations:
# 1.) It is an Excel file
#
# 2.) Extra rows have been spoted for spacing
#
# 3.) Unnecessary columns are also seen
#
# 4.) The only source of expence is Counter book
#
# 5.) Further investigation needed
#
# 6.) Total Expenditure is 3,40,034/-
#
# 7.) Total Cash Inflow is 6,65,655/-
#
# 8.) Total Profit is 3,25,621/-
#
# #### Recommendation:
# 1.)Use of pandas of cleaning
#
# 2.)Use of numpy for numbers
#
# 3.)Accuracy till 2 decimal places will be good enough
#
# 4.)Scientific notations not needed
#
# 5.)Data consistency is in question

# %%
import numpy as np
import pandas as pd
np.set_printoptions(suppress = True,
                   linewidth = 100,
                   precision = 2)
#According to recommendations files have been imported
#precision set and scientific notations are suppressed

# %% [markdown]
# # Cash Out Flow

# %%
#importing data
salesData = pd.read_excel("July2023ExpenseReport.xlsx")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
salesData
# Out:
#           Date Month       Expense Details   Amount         Catagory  \
# 0   2023-07-01  July        Indian Broiler   7785.0       01_Non Veg
# 1   2023-07-01  July        Emergency chef   3000.0        04_Salary
# 2   2023-07-01  July             Kapil ODC    500.0           04_ODC
# 3   2023-07-01  July      Ya Taj Beverages  15000.0          03_Misc
# 4   2023-07-01  July           Electrician   3000.0  03_Maintainance
# ..         ...   ...                   ...      ...              ...
# 105 2023-07-20  July  Yuvraj full sal June   6500.0        04_Salary
# 106        NaT   NaN                   NaN      NaN              NaN
# 107 2023-07-21  July          French fries    380.0         01_Dairy
# 108 2023-07-21  July                Corn 2    240.0         01_Dairy
# 109 2023-07-21  July  Pankaj full sal June   7800.0        04_Salary
#
#        Exp Source
# 0    Counter Book
# 1    Counter Book
# 2    Counter Book
# 3    Counter Book
# 4    Counter Book
# ..            ...
# ...

# %%
salesData = salesData.dropna(how='all')
#removed unnecessary blank rows

# %%
salesData
# Out:
#           Date Month       Expense Details   Amount         Catagory  \
# 0   2023-07-01  July        Indian Broiler   7785.0       01_Non Veg
# 1   2023-07-01  July        Emergency chef   3000.0        04_Salary
# 2   2023-07-01  July             Kapil ODC    500.0           04_ODC
# 3   2023-07-01  July      Ya Taj Beverages  15000.0          03_Misc
# 4   2023-07-01  July           Electrician   3000.0  03_Maintainance
# ..         ...   ...                   ...      ...              ...
# 104 2023-07-20  July        Ankit July adv   1000.0        04_Salary
# 105 2023-07-20  July  Yuvraj full sal June   6500.0        04_Salary
# 107 2023-07-21  July          French fries    380.0         01_Dairy
# 108 2023-07-21  July                Corn 2    240.0         01_Dairy
# 109 2023-07-21  July  Pankaj full sal June   7800.0        04_Salary
#
#        Exp Source
# 0    Counter Book
# 1    Counter Book
# 2    Counter Book
# 3    Counter Book
# 4    Counter Book
# ..            ...
# ...

# %%
salesData.drop("Month",axis=1,inplace=True)
#No need of months column the dates show the month
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13264\2824999671.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salesData.drop("Month",axis=1,inplace=True)

# %%
salesData
# Out:
#           Date       Expense Details   Amount         Catagory    Exp Source
# 0   2023-07-01        Indian Broiler   7785.0       01_Non Veg  Counter Book
# 1   2023-07-01        Emergency chef   3000.0        04_Salary  Counter Book
# 2   2023-07-01             Kapil ODC    500.0           04_ODC  Counter Book
# 3   2023-07-01      Ya Taj Beverages  15000.0          03_Misc  Counter Book
# 4   2023-07-01           Electrician   3000.0  03_Maintainance  Counter Book
# ..         ...                   ...      ...              ...           ...
# 104 2023-07-20        Ankit July adv   1000.0        04_Salary  Counter Book
# 105 2023-07-20  Yuvraj full sal June   6500.0        04_Salary  Counter Book
# 107 2023-07-21          French fries    380.0         01_Dairy  Counter Book
# 108 2023-07-21                Corn 2    240.0         01_Dairy  Counter Book
# 109 2023-07-21  Pankaj full sal June   7800.0        04_Salary  Counter Book
#
# [90 rows x 5 columns]

# %%
salesData["Catagory"].unique()
# Out:
# array(['01_Non Veg', '04_Salary', '04_ODC', '03_Misc', '03_Maintainance', '03_Petrol', '02_Gas',
#        '02_Coal', '04_Salary OT', '04_Samaj seva', '01_Fish', '01_Dairy', '01_Chicken',
#        '03_Room Rent'], dtype=object)

# %%
salesData["Catagory"].unique().size
#so the number of categories are 14
# Out:
# 14

# %%
salesData.drop("Exp Source", axis=1, inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13264\2634942098.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salesData.drop("Exp Source", axis=1, inplace=True)

# %%
salesData
# Out:
#           Date       Expense Details   Amount         Catagory
# 0   2023-07-01        Indian Broiler   7785.0       01_Non Veg
# 1   2023-07-01        Emergency chef   3000.0        04_Salary
# 2   2023-07-01             Kapil ODC    500.0           04_ODC
# 3   2023-07-01      Ya Taj Beverages  15000.0          03_Misc
# 4   2023-07-01           Electrician   3000.0  03_Maintainance
# ..         ...                   ...      ...              ...
# 104 2023-07-20        Ankit July adv   1000.0        04_Salary
# 105 2023-07-20  Yuvraj full sal June   6500.0        04_Salary
# 107 2023-07-21          French fries    380.0         01_Dairy
# 108 2023-07-21                Corn 2    240.0         01_Dairy
# 109 2023-07-21  Pankaj full sal June   7800.0        04_Salary
#
# [90 rows x 4 columns]

# %%
salesData.set_index("Date")
# Out:
#                  Expense Details   Amount         Catagory
# Date
# 2023-07-01        Indian Broiler   7785.0       01_Non Veg
# 2023-07-01        Emergency chef   3000.0        04_Salary
# 2023-07-01             Kapil ODC    500.0           04_ODC
# 2023-07-01      Ya Taj Beverages  15000.0          03_Misc
# 2023-07-01           Electrician   3000.0  03_Maintainance
# ...                          ...      ...              ...
# 2023-07-20        Ankit July adv   1000.0        04_Salary
# 2023-07-20  Yuvraj full sal June   6500.0        04_Salary
# 2023-07-21          French fries    380.0         01_Dairy
# 2023-07-21                Corn 2    240.0         01_Dairy
# 2023-07-21  Pankaj full sal June   7800.0        04_Salary
#
# [90 rows x 3 columns]

# %% [markdown]
# <hr style="border: 1px solid black;">

# %%
salesData["Amount"].array.sum()
#the total has been removed
# Out:
# 340034.0

# %% [markdown]
# <hr style="border: 1px solid black;">

# %%
salesData["Expense Details"].unique().size
# Out:
# 74

# %%
salesData["Expense Details"].unique()
# Out:
# array(['Indian Broiler', 'Emergency chef', 'Kapil ODC', 'Ya Taj Beverages', 'Electrician',
#        'staff party', 'Vishal salary adv.', 'Ajay May salary', 'Ajay June salary adv', 'Hardware',
#        'Tija bai', 'Ankit chef', 'sunita Bai', 'Yuvraj Chef', 'Omni petrol', 'Sarswati Bai',
#        'Nagpur Hardware', 'Deepak chef', 'Plumber', 'Petrol', 'Kartik salary adv', 'Ashok watt',
#        'Small gas', 'Golu salary (June)', 'Ajay salary adv june', 'Dheeraj chef', 'Labour',
#        'Coal ', 'Beverages ya taj', 'Ankit chef OT', 'Sagar painter', 'Rao NHAI', 'Samaj seva',
#        'Fish', 'Green peas', 'Water bottles', 'Milind Plumber', 'Fabricator', 'Screw', 'Van tube',
#        'Milind final ', 'Coal payment', 'Korde kaka June salary', 'Tarachand kaka full Jan salary',
#        'Tija bai full sal June', 'Sunita bai full sal June', 'India broiler full payment',
#        'Saraswati bai full sal June', 'Sumitra bai full sal June', 'Arvind July adv',
# ...

# %%
unique_values=salesData["Expense Details"].unique()

# %%
salesData["Expense Details"].value_counts()
# Out:
# Expense Details
# Omni petrol             12
# Fabricator               2
# Dhiraj July adv          2
# Arvind July adv          2
# Deepak chef              2
#                         ..
# Labour                   1
# Dheeraj chef             1
# Ajay salary adv june     1
# Golu salary (June)       1
# Pankaj full sal June     1
# Name: count, Length: 74, dtype: int64

# %%
salesData["Expense Details"].value_counts().to_excel("Expense_Details_frequency.xlsx")

# %% [markdown]
# ## This code gives the total amount spent on various Sub-Cat

# %%
loop_output ={}
for i in unique_values:
    key = f'{i}'
    details=salesData[salesData["Expense Details"].str.startswith(i)]["Amount"].array.sum()
    loop_output[key]=details

# %%
loop_output
# Out:
# {'Indian Broiler': 7785.0,
#  'Emergency chef': 3000.0,
#  'Kapil ODC': 500.0,
#  'Ya Taj Beverages': 15000.0,
#  'Electrician': 3000.0,
#  'staff party': 2000.0,
#  'Vishal salary adv.': 2000.0,
#  'Ajay May salary': 3165.0,
#  'Ajay June salary adv': 1000.0,
#  'Hardware': 212.0,
#  'Tija bai': 5500.0,
#  'Ankit chef': 4000.0,
#  'sunita Bai': 3000.0,
#  'Yuvraj Chef': 1000.0,
#  'Omni petrol': 6500.0,
#  'Sarswati Bai': 1000.0,
#  'Nagpur Hardware': 13670.0,
#  'Deepak chef': 1130.0,
#  'Plumber': 2000.0,
#  'Petrol': 1000.0,
#  'Kartik salary adv': 500.0,
#  'Ashok watt': 1450.0,
#  'Small gas': 1200.0,
#  'Golu salary (June)': 8500.0,
#  'Ajay salary adv june': 5000.0,
#  'Dheeraj chef': 300.0,
#  'Labour': 1500.0,
#  'Coal ': 18000.0,
#  'Beverages ya taj': 10000.0,
#  'Ankit chef OT': 500.0,
#  'Sagar painter': 5000.0,
#  'Rao NHAI': 25000.0,
#  'Samaj seva': 25000.0,
#  'Fish': 200.0,
#  'Green peas': 240.0,
#  'Water bottles': 200.0,
#  'Milind Plumber': 4500.0,
# ...

# %%
type(loop_output)
# Out:
# dict

# %%
sub_cat = pd.DataFrame(loop_output, index=range(1))

# %%
sub_cat
# Out:
#    Indian Broiler  Emergency chef  Kapil ODC  Ya Taj Beverages  Electrician  \
# 0          7785.0          3000.0      500.0           15000.0       3000.0
#
#    staff party  Vishal salary adv.  Ajay May salary  Ajay June salary adv  \
# 0       2000.0              2000.0           3165.0                1000.0
#
#    Hardware  ...  Dhiraj July adv  Ankit Full sal  Shubham full sal June  \
# 0     212.0  ...            603.0          8500.0                 5200.0
#
#    Omni Petrol  Sunny July adv  Ankit July adv  Yuvraj full sal June  \
# 0        500.0          2000.0          1000.0                6500.0
#
#    French fries  Corn 2  Pankaj full sal June
# 0         380.0   240.0                7800.0
#
# [1 rows x 74 columns]

# %%
salesData["Expense Details"].isna().sum()
# Out:
# 0

# %%
sub_cat.to_excel("Sub-Cateogrised=Expenses.xlsx", index=False)

# %% [markdown]
# # Cash Inflow Data

# %%
cashInData = pd.read_excel("July2023IncashReport.xlsx")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
cashInData
# Out:
#          DATE Month        Details      CATEGORY   Amount
# 0  2023-07-01  July   Counter cash  Counter Book  52357.0
# 1  2023-07-01  July  Siddhart cash  Counter Book  16000.0
# 2         NaT   NaN            NaN           NaN      NaN
# 3  2023-07-02  July   Counter cash  Counter Book  31197.0
# 4  2023-07-02  July  Siddhart cash  Counter Book   6000.0
# ..        ...   ...            ...           ...      ...
# 56 2023-07-20  July   Counter cash  Counter Book  22891.0
# 57 2023-07-20  July  Siddhart cash  Counter Book   7500.0
# 58        NaT   NaN            NaN           NaN      NaN
# 59 2023-07-21  July   Counter cash  Counter Book  13563.0
# 60 2023-07-21  July  siddhart cash  Counter Book   5500.0
#
# [61 rows x 5 columns]

# %%
cashInData = cashInData.dropna(how='all')
#removed unnecessary blank rows

# %%
cashInData
# Out:
#          DATE Month             Details      CATEGORY   Amount
# 0  2023-07-01  July        Counter cash  Counter Book  52357.0
# 1  2023-07-01  July       Siddhart cash  Counter Book  16000.0
# 3  2023-07-02  July        Counter cash  Counter Book  31197.0
# 4  2023-07-02  July       Siddhart cash  Counter Book   6000.0
# 6  2023-07-03  July        Counter cash  Counter Book   6791.0
# 7  2023-07-03  July       siddhart cash  Counter Book   3500.0
# 8  2023-07-03  July        Card payment  Counter Book   2230.0
# 10 2023-07-04  July        Counter cash  Counter Book  13662.0
# 11 2023-07-04  July       Siddhart cash  Counter Book  11500.0
# 13 2023-07-05  July        Counter cash  Counter Book  17415.0
# 14 2023-07-05  July  Nilesh sir car EMI  Counter Book   6700.0
# 16 2023-07-06  July        Counter cash  Counter Book  15464.0
# 17 2023-07-06  July       siddhart cash  Counter Book  11000.0
# 19 2023-07-07  July        Counter cash  Counter Book  33099.0
# ...

# %%
cashInData["Amount"].array.sum()
#total cash inflow
# Out:
# 665655.0

# %%
cashInData=cashInData.set_index("DATE")
#setting date as index

# %%
cashInData.drop("Month",axis=1,inplace=True)
#No need of months column the dates show the month

# %%
cashInData
# Out:
#                        Details      CATEGORY   Amount
# DATE
# 2023-07-01        Counter cash  Counter Book  52357.0
# 2023-07-01       Siddhart cash  Counter Book  16000.0
# 2023-07-02        Counter cash  Counter Book  31197.0
# 2023-07-02       Siddhart cash  Counter Book   6000.0
# 2023-07-03        Counter cash  Counter Book   6791.0
# 2023-07-03       siddhart cash  Counter Book   3500.0
# 2023-07-03        Card payment  Counter Book   2230.0
# 2023-07-04        Counter cash  Counter Book  13662.0
# 2023-07-04       Siddhart cash  Counter Book  11500.0
# 2023-07-05        Counter cash  Counter Book  17415.0
# 2023-07-05  Nilesh sir car EMI  Counter Book   6700.0
# 2023-07-06        Counter cash  Counter Book  15464.0
# 2023-07-06       siddhart cash  Counter Book  11000.0
# 2023-07-07        Counter cash  Counter Book  33099.0
# 2023-07-07       siddhart cash  Counter Book  10500.0
# 2023-07-08        Counter cash  Counter Book  55144.0
# ...

# %%
cashInData["CATEGORY"].unique()
# Out:
# array(['Counter Book'], dtype=object)

# %%
cashInData.drop("CATEGORY",axis=1,inplace=True)

# %%
cashInData
# Out:
#                        Details   Amount
# DATE
# 2023-07-01        Counter cash  52357.0
# 2023-07-01       Siddhart cash  16000.0
# 2023-07-02        Counter cash  31197.0
# 2023-07-02       Siddhart cash   6000.0
# 2023-07-03        Counter cash   6791.0
# 2023-07-03       siddhart cash   3500.0
# 2023-07-03        Card payment   2230.0
# 2023-07-04        Counter cash  13662.0
# 2023-07-04       Siddhart cash  11500.0
# 2023-07-05        Counter cash  17415.0
# 2023-07-05  Nilesh sir car EMI   6700.0
# 2023-07-06        Counter cash  15464.0
# 2023-07-06       siddhart cash  11000.0
# 2023-07-07        Counter cash  33099.0
# 2023-07-07       siddhart cash  10500.0
# 2023-07-08        Counter cash  55144.0
# 2023-07-09        Counter cash  24260.0
# 2023-07-09       Siddhart cash   9000.0
# 2023-07-10        Counter cash  18111.0
# 2023-07-10       Siddhart cash   4000.0
# 2023-07-11        Counter cash  10316.0
# 2023-07-11       Siddhart cash   5000.0
# ...

# %%
cashInData["Details"].unique()
# Out:
# array(['Counter cash', 'Siddhart cash', 'siddhart cash', 'Card payment', 'Nilesh sir car EMI',
#        'Counter cash ', 'Siddhart  cash'], dtype=object)

# %%
cashInData["Details"] = np.where(cashInData["Details"] == "Counter cash ",
                     "Counter cash",
                     cashInData["Details"])

# %%
cashInData
# Out:
#                        Details   Amount
# DATE
# 2023-07-01        Counter cash  52357.0
# 2023-07-01       Siddhart cash  16000.0
# 2023-07-02        Counter cash  31197.0
# 2023-07-02       Siddhart cash   6000.0
# 2023-07-03        Counter cash   6791.0
# 2023-07-03       siddhart cash   3500.0
# 2023-07-03        Card payment   2230.0
# 2023-07-04        Counter cash  13662.0
# 2023-07-04       Siddhart cash  11500.0
# 2023-07-05        Counter cash  17415.0
# 2023-07-05  Nilesh sir car EMI   6700.0
# 2023-07-06        Counter cash  15464.0
# 2023-07-06       siddhart cash  11000.0
# 2023-07-07        Counter cash  33099.0
# 2023-07-07       siddhart cash  10500.0
# 2023-07-08        Counter cash  55144.0
# 2023-07-09        Counter cash  24260.0
# 2023-07-09       Siddhart cash   9000.0
# 2023-07-10        Counter cash  18111.0
# 2023-07-10       Siddhart cash   4000.0
# 2023-07-11        Counter cash  10316.0
# 2023-07-11       Siddhart cash   5000.0
# ...

# %%
cashInData["Details"].value_counts()
# Out:
# Details
# Counter cash          21
# Siddhart cash         13
# siddhart cash          4
# Card payment           1
# Nilesh sir car EMI     1
# Siddhart  cash         1
# Name: count, dtype: int64

# %%
loop_output_incash ={}
for i in cashInData["Details"].unique():
    key = f'{i}'
    details= cashInData[cashInData["Details"].str.startswith(i)]["Amount"].array.sum()
    loop_output_incash[key]=details

# %%
loop_output_incash
# Out:
# {'Counter cash': 498225.0,
#  'Siddhart cash': 116000.0,
#  'siddhart cash': 30500.0,
#  'Card payment': 2230.0,
#  'Nilesh sir car EMI': 6700.0,
#  'Siddhart  cash': 12000.0}
